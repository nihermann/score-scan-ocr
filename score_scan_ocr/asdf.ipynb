# %%
from utx.plx import plx, ishow
import numpy as np
import matplotlib.pyplot as plt
import cv2
from scipy.stats import gaussian_kde

from pdfs.handle import Pdf

# %%
f = Pdf.from_file("Armenian Dances - Reed Alfred.pdf")
p = f.page_as_img(0)
ishow(p)
ph = cv2.cvtColor(p, cv2.COLOR_RGB2HSV)
p[ph[..., 1] > 40, :] = 255
ishow(p)

# %%
# Out:
# array([[   0,    0],
#        [   0,    1],
#        [   0,    2],
#        ...,
#        [ 863, 2589],
#        [ 863, 2590],
#        [ 863, 2591]])
